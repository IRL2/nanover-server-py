# %%
import pandas as pd
import re

FILENAME = "com.IntangibleRealitiesLaboratory.NanoVeriMD#UnityPlayerGameActivity-20260320_164140.csv"

parse = re.search('_([0-9][0-9])([0-9][0-9])([0-9][0-9])', FILENAME, re.IGNORECASE)
print(":".join(list(parse.groups())))

msft = pd.read_csv(FILENAME)

msft.plot("Time Stamp", ["average_frame_rate"], subplots=True)

# print([time/1000 for time in msft["Time Stamp"]])
#
# 2026-03-20 16:41:57.690046
# 2026-03-20 16:41:59.766025 scaled_water_xml_files/solvent-000900.xml
# 2026-03-20 16:42:29.774137 scaled_water_xml_files/solvent-001500.xml
# 2026-03-20 16:42:59.778071 scaled_water_xml_files/solvent-002100.xml
# 2026-03-20 16:43:29.809330 scaled_water_xml_files/solvent-002700.xml
# 2026-03-20 16:43:59.814779 scaled_water_xml_files/solvent-006000.xml
# 2026-03-20 16:44:29.835756 scaled_water_xml_files/solvent-012000.xml
# 2026-03-20 16:44:59.849122 scaled_water_xml_files/solvent-018000.xml
# Out:
# 16:41:40
# array([<Axes: xlabel='Time Stamp'>], dtype=object)

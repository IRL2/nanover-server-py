# %%
import pandas as pd
import re

FILENAME = "GFX-TEST-20260320_121950.csv"

parse = re.search('_([0-9][0-9])([0-9][0-9])([0-9][0-9])', FILENAME, re.IGNORECASE)
print(":".join(list(parse.groups())))

msft = pd.read_csv("GFX-TEST-20260320_121950.csv")

msft.plot("Time Stamp", ["average_frame_rate"], subplots=True)

print([time/1000 for time in msft["Time Stamp"]])
# Out:
# 12:19:50
# [0.971, 1.971, 2.971, 3.971, 4.971, 5.971, 6.975, 7.971, 8.973, 9.972, 10.972, 11.972, 12.972, 13.972, 14.972, 15.972, 16.972, 17.972, 18.972, 20.008, 20.973, 21.973, 22.973, 23.973, 24.973, 25.973, 26.973, 27.973, 28.973, 29.973, 30.973, 31.973, 32.974, 33.973, 34.974, 35.974, 36.974, 37.974, 38.974, 40.013, 40.975, 41.975, 42.975]

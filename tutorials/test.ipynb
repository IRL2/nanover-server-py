# %%
from nanover.openmm.serializer import deserialize_simulation
from nanover.openmm.bundle import bundle_openmm_simulation

with open("ase/openmm_files/neuraminidase_restrained.xml") as infile:
    simulation = deserialize_simulation(infile.read())
bundle_openmm_simulation(simulation, outfile="example_systems/neuraminidase_restrained.openmm.zip")

# %%
from nanover.openmm.bundle import unbundle_openmm_simulation

unbundle_openmm_simulation("example_systems/neuraminidase.openmm.zip")

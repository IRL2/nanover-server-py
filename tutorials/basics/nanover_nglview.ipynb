# %% [markdown]
# # Interactive NanoVer Client with NGLView

# %% [markdown]
# This notebook assumes a NanoVer frame server is running, and lets you visualise it as a live trajectory with NGLView

# %%
from nanover.jupyter import NGLClient

# %%
# NBVAL_RAISES_EXCEPTION
client = NGLClient.from_discovery()
# Out:
# DEPRECATED: Please use 'center' method
# DEPRECATED: Please use 'center' method
# DEPRECATED: Please use 'center' method
# DEPRECATED: Please use 'center' method
# DEPRECATED: Please use 'center' method

# %%
# NBVAL_SKIP
client.view
# Out:
# NGLWidget()

# %%
# NBVAL_SKIP
from nanover.jupyter import show_app_server_controls

show_app_server_controls(client)
# Out:
# interactive(children=(Dropdown(description='Force Type', index=1, options=(('Gaussian', 'gaussian'), ('Harmoni…
# interactive(children=(IntSlider(value=100, description='Force Scale', max=1000, min=1), Output()), _dom_classe…
# interactive(children=(FloatSlider(value=0.4, description='Force Range', max=2.0, min=0.1, step=0.05), Output()…
# interactive(children=(FloatSlider(value=1.0, description='Passthrough', max=1.0), Output()), _dom_classes=('wi…
# HBox(children=(VBox(children=(Button(description='Reset Molecule', style=ButtonStyle()), ToggleButton(value=Fa…
